# %% [markdown]
# ## de Ferra, Mitman, and Romei (2019) — Ballpark Entry
#
# **Paper:** {cite:t}`de-Ferra2019-co`
#
# ---
#
# *Add a brief intro to the paper. Base this on your reading of the de Ferra, Mitman & Romei (2019) NBER working paper.*
