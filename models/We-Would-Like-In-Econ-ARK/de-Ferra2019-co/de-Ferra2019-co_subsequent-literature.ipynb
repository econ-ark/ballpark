# %% [markdown]
# ## Subsequent Literature
#
# *Identify papers that build on or extend {cite:t}`de-Ferra2019-co`. Add their BibTeX entries to subsequent-literature.bib, then cite using {cite:t}`citekey`.*
