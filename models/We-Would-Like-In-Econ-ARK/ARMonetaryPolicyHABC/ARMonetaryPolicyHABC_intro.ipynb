# %% [markdown]
# # Algan and Ragot (2009)
#
# ## Paper Information
#
# **Title:** Monetary policy with heterogeneous agents and borrowing constraints
#
# **Authors:** Yann Algan and Xavier Ragot
#
# **Year:** 2009
#
# **Link:** [Paper PDF](https://spire.sciencespo.fr/hdl:/2441/3ao9avev669hj9hvol1l0lr6im/resources/2010-algan-ragot-monetary-policy.pdf)
#
# ## Notebook Authorship
#
# - **Original notebook author:** Sinem Yagmur Toraman
# - **Contributor:** Asiye Irem Desdemir
# - **Dates:** October 6, 2020 - February 9, 2026
#
# ## Overview
#
# This notebook series provides a comprehensive analysis of {cite:t}`algan2009monetary`, examining how monetary policy operates in an economy with heterogeneous agents and borrowing constraints. The analysis is organized into four parts:
#
# 1. **[Introduction](ARMonetaryPolicyHABC_intro.ipynb)** (this notebook) - Paper metadata and overview
# 2. **[Prior Literature](ARMonetaryPolicyHABC_prior-literature.ipynb)** - Foundational work and theoretical background
# 3. **[Summary](ARMonetaryPolicyHABC_summary.ipynb)** - Detailed summary of the paper's model, results, and contributions
# 4. **[Subsequent Literature](ARMonetaryPolicyHABC_subsequent-literature.ipynb)** - Research building on Algan and Ragot (2009)
#
# ## Key Contribution
#
# The paper shows that **inflation is no longer neutral for long-run capital accumulation once incomplete markets are taken seriously**. Rather than operating through a representative-agent channel, inflation affects the economy through asymmetric portfolio adjustment across constrained and unconstrained households, generating a hump-shaped relationship between inflation and aggregate capital that is consistent with empirical evidence.
